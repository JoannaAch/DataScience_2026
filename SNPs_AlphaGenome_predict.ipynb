# %% [markdown]
# <a href="https://colab.research.google.com/github/JoannaAch/DataScience_2026/blob/main/SNPs_AlphaGenome_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Install AlphaGenome

# @markdown Run this cell to install AlphaGenome.
from IPython.display import clear_output
! pip install alphagenome
clear_output()

# %%
from alphagenome import colab_utils
from alphagenome.data import gene_annotation, genome, track_data, transcript
from alphagenome.models import dna_client
from alphagenome.visualization import plot_components
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dna_model = dna_client.create(colab_utils.get_api_key())

# %%
# Load metadata objects for human.
output_metadata = dna_model.output_metadata(
    organism=dna_client.Organism.HOMO_SAPIENS
)
output_metadata
# Out:
# OutputMetadata(atac=                        name strand Assay title  ontology_curie  \
# 0        CL:0000084 ATAC-seq      .    ATAC-seq      CL:0000084
# 1        CL:0000100 ATAC-seq      .    ATAC-seq      CL:0000100
# 2        CL:0000236 ATAC-seq      .    ATAC-seq      CL:0000236
# 3        CL:0000623 ATAC-seq      .    ATAC-seq      CL:0000623
# 4        CL:0000624 ATAC-seq      .    ATAC-seq      CL:0000624
# ..                       ...    ...         ...             ...
# 162  UBERON:0008953 ATAC-seq      .    ATAC-seq  UBERON:0008953
# 163  UBERON:0008971 ATAC-seq      .    ATAC-seq  UBERON:0008971
# 164  UBERON:0010414 ATAC-seq      .    ATAC-seq  UBERON:0010414
# 165  UBERON:0011907 ATAC-seq      .    ATAC-seq  UBERON:0011907
# 166  UBERON:0015143 ATAC-seq      .    ATAC-seq  UBERON:0015143
#
#                       biosample_name                 biosample_type  \
# 0                             T-cell                   primary_cell
# 1                       motor neuron  in_vitro_differentiated_cells
# 2                             B cell                   primary_cell
# 3                natural killer cell                   primary_cell
# 4    CD4-positive, alpha-beta T cell                   primary_cell
# ..                               ...                            ...
# 162          lower lobe of left lung                         tissue
# 163                       left colon                         tissue
# 164                  omental fat pad                         tissue
# 165           gastrocnemius medialis                         tissue
# 166               mesenteric fat pad                         tissue
#
#     biosample_life_stage data_source endedness  genetically_modified  \
# 0                  adult      encode    paired                 False
# 1                  adult      encode    paired                 False
# 2                  adult      encode    paired                 False
# 3                  adult      encode    paired                 False
# 4                  adult      encode    paired                 False
# ..                   ...         ...       ...                   ...
# 162                adult      encode    paired                 False
# 163                adult      encode    paired                 False
# 164                adult      encode    paired                 False
# 165                adult      encode    paired                 False
# 166                adult      encode    paired                 False
#
#      nonzero_mean
# 0        0.739741
# 1        0.273136
# 2        4.700081
# 3        0.938715
# 4        4.365206
# ..            ...
# 162      0.312247
# 163      0.675871
# 164      1.118522
# 165      0.811485
# 166      0.420261
#
# [167 rows x 11 columns], cage=                     name strand Assay title  ontology_curie  \
# 0      LQhCAGE CL:0000077      +     LQhCAGE      CL:0000077
# 1      LQhCAGE CL:0000136      +     LQhCAGE      CL:0000136
# 2      LQhCAGE CL:0000767      +     LQhCAGE      CL:0000767
# 3      LQhCAGE CL:0000771      +     LQhCAGE      CL:0000771
# 4      LQhCAGE CL:0000775      +     LQhCAGE      CL:0000775
# ..                    ...    ...         ...             ...
# 541  hCAGE UBERON:0006659      -       hCAGE  UBERON:0006659
# 542  hCAGE UBERON:0007023      -       hCAGE  UBERON:0007023
# 543  hCAGE UBERON:0007190      -       hCAGE  UBERON:0007190
# 544  hCAGE UBERON:0008198      -       hCAGE  UBERON:0008198
# 545  hCAGE UBERON:0013777      -       hCAGE  UBERON:0013777
#
#                 biosample_name biosample_type data_source  nonzero_mean
# 0             mesothelial cell   primary_cell      fantom    272.418427
# 1                     fat cell   primary_cell      fantom     41.716267
# 2                     basophil   primary_cell      fantom     59.455761
# 3                   eosinophil   primary_cell      fantom    119.224518
# 4                   neutrophil   primary_cell      fantom    339.387207
# ..                         ...            ...         ...           ...
# 541  cruciate ligament of knee         tissue      fantom     23.395981
# 542             adult organism   primary_cell      fantom     53.722767
# 543          paracentral gyrus         tissue      fantom     29.090841
# 544                 nail plate         tissue      fantom     43.569462
# 545      skin of palm of manus         tissue      fantom     43.870785
#
# [546 rows x 8 columns], dnase=                         name strand Assay title  ontology_curie  \
# 0        CL:0000047 DNase-seq      .   DNase-seq      CL:0000047
# 1        CL:0000084 DNase-seq      .   DNase-seq      CL:0000084
# 2        CL:0000115 DNase-seq      .   DNase-seq      CL:0000115
# 3        CL:0000127 DNase-seq      .   DNase-seq      CL:0000127
# 4        CL:0000134 DNase-seq      .   DNase-seq      CL:0000134
# ..                        ...    ...         ...             ...
# 300  UBERON:0036149 DNase-seq      .   DNase-seq  UBERON:0036149
# 301  UBERON:8300001 DNase-seq      .   DNase-seq  UBERON:8300001
# 302  UBERON:8300002 DNase-seq      .   DNase-seq  UBERON:8300002
# 303  UBERON:8300003 DNase-seq      .   DNase-seq  UBERON:8300003
# 304  UBERON:8300004 DNase-seq      .   DNase-seq  UBERON:8300004
#
#             biosample_name                 biosample_type  \
# 0       neuronal stem cell  in_vitro_differentiated_cells
# 1                   T-cell                   primary_cell
# 2         endothelial cell  in_vitro_differentiated_cells
# 3                astrocyte                   primary_cell
# 4    mesenchymal stem cell  in_vitro_differentiated_cells
# ..                     ...                            ...
# 300        suprapubic skin                         tissue
# 301         right forelimb                         tissue
# 302          left forelimb                         tissue
# 303         right hindlimb                         tissue
# 304          left hindlimb                         tissue
#
#     biosample_life_stage data_source endedness  genetically_modified  \
# 0              embryonic      encode    single                 False
# 1                  adult      encode    paired                 False
# 2                  adult      encode    paired                 False
# 3                unknown      encode    single                 False
# 4              embryonic      encode    paired                 False
# ..                   ...         ...       ...                   ...
# 300                adult      encode    paired                 False
# 301            embryonic      encode    paired                 False
# 302            embryonic      encode    paired                 False
# 303            embryonic      encode    paired                 False
# 304            embryonic      encode    paired                 False
#
#      nonzero_mean
# 0        1.554501
# 1        0.151404
# 2        0.513028
# 3        0.845752
# 4        0.540044
# ..            ...
# 300      0.485925
# 301      1.431965
# 302      1.206352
# 303      1.254712
# 304      1.946842
#
# [305 rows x 11 columns], rna_seq=                                                  name strand  \
# 0                        CL:0000047 polyA plus RNA-seq      +
# 1                             CL:0000062 total RNA-seq      +
# 2                        CL:0000084 polyA plus RNA-seq      +
# 3                             CL:0000084 total RNA-seq      +
# 4                             CL:0000115 total RNA-seq      +
# ..                                                 ...    ...
# 662                  UBERON:0018115 polyA plus RNA-seq      .
# 663                  UBERON:0018116 polyA plus RNA-seq      .
# 664                  UBERON:0018117 polyA plus RNA-seq      .
# 665                  UBERON:0018118 polyA plus RNA-seq      .
# 666  UBERON:0036149 gtex Skin_Not_Sun_Exposed_Supra...      .
#
#             Assay title  ontology_curie                   biosample_name  \
# 0    polyA plus RNA-seq      CL:0000047               neuronal stem cell
# 1         total RNA-seq      CL:0000062                       osteoblast
# 2    polyA plus RNA-seq      CL:0000084                           T-cell
# 3         total RNA-seq      CL:0000084                           T-cell
# 4         total RNA-seq      CL:0000115                 endothelial cell
# ..                  ...             ...                              ...
# 662  polyA plus RNA-seq  UBERON:0018115                left renal pelvis
# 663  polyA plus RNA-seq  UBERON:0018116               right renal pelvis
# 664  polyA plus RNA-seq  UBERON:0018117   left renal cortex interstitium
# 665  polyA plus RNA-seq  UBERON:0018118  right renal cortex interstitium
# 666  polyA plus RNA-seq  UBERON:0036149                  suprapubic skin
#
#                     biosample_type biosample_life_stage  \
# 0    in_vitro_differentiated_cells            embryonic
# 1                     primary_cell                adult
# 2                     primary_cell                adult
# 3                     primary_cell                adult
# 4    in_vitro_differentiated_cells                adult
# ..                             ...                  ...
# 662                         tissue            embryonic
# 663                         tissue            embryonic
# 664                         tissue            embryonic
# 665                         tissue            embryonic
# 666                         tissue                adult
#
#                          gtex_tissue data_source endedness  \
# 0                                         encode    paired
# 1                                         encode    paired
# 2                                         encode    paired
# 3                                         encode    single
# 4                                         encode    single
# ..                               ...         ...       ...
# 662                                       encode    single
# 663                                       encode    single
# 664                                       encode    single
# 665                                       encode    single
# 666  Skin_Not_Sun_Exposed_Suprapubic        gtex    paired
#
#      genetically_modified  nonzero_mean
# 0                   False      0.143617
# 1                   False      0.094144
# 2                   False      0.124296
# 3                   False      0.100934
# 4                   False      0.135553
# ..                    ...           ...
# 662                 False      0.268222
# 663                 False      0.258522
# 664                 False      0.215190
# 665                 False      0.365676
# 666                 False      0.045404
#
# [667 rows x 12 columns], chip_histone=                                          name strand       Assay title  \
# 0            CL:0000047 Histone ChIP-seq H2AFZ      .  Histone ChIP-seq
# 1          CL:0000047 Histone ChIP-seq H2AK5ac      .  Histone ChIP-seq
# 2          CL:0000047 Histone ChIP-seq H2BK5ac      .  Histone ChIP-seq
# 3          CL:0000047 Histone ChIP-seq H3K18ac      .  Histone ChIP-seq
# 4          CL:0000047 Histone ChIP-seq H3K27ac      .  Histone ChIP-seq
# ...                                        ...    ...               ...
# 1111   UBERON:0036149 Histone ChIP-seq H3K27ac      .  Histone ChIP-seq
# 1112  UBERON:0036149 Histone ChIP-seq H3K27me3      .  Histone ChIP-seq
# 1113  UBERON:0036149 Histone ChIP-seq H3K36me3      .  Histone ChIP-seq
# 1114   UBERON:0036149 Histone ChIP-seq H3K4me1      .  Histone ChIP-seq
# 1115   UBERON:0036149 Histone ChIP-seq H3K4me3      .  Histone ChIP-seq
#
#       ontology_curie      biosample_name                 biosample_type  \
# 0         CL:0000047  neuronal stem cell  in_vitro_differentiated_cells
# 1         CL:0000047  neuronal stem cell  in_vitro_differentiated_cells
# 2         CL:0000047  neuronal stem cell  in_vitro_differentiated_cells
# 3         CL:0000047  neuronal stem cell  in_vitro_differentiated_cells
# 4         CL:0000047  neuronal stem cell  in_vitro_differentiated_cells
# ...              ...                 ...                            ...
# 1111  UBERON:0036149     suprapubic skin                         tissue
# 1112  UBERON:0036149     suprapubic skin                         tissue
# 1113  UBERON:0036149     suprapubic skin                         tissue
# 1114  UBERON:0036149     suprapubic skin                         tissue
# 1115  UBERON:0036149     suprapubic skin                         tissue
#
#      biosample_life_stage histone_mark data_source endedness  \
# 0               embryonic        H2AFZ      encode    single
# 1               embryonic      H2AK5ac      encode    single
# 2               embryonic      H2BK5ac      encode    single
# 3               embryonic      H3K18ac      encode    single
# 4               embryonic      H3K27ac      encode    single
# ...                   ...          ...         ...       ...
# 1111                adult      H3K27ac      encode    single
# 1112                adult     H3K27me3      encode    single
# 1113                adult     H3K36me3      encode    single
# 1114                adult      H3K4me1      encode    single
# 1115                adult      H3K4me3      encode    single
#
#       genetically_modified  nonzero_mean
# 0                    False      0.953686
# 1                    False      0.819365
# 2                    False      1.039205
# 3                    False      1.050094
# 4                    False      0.785182
# ...                    ...           ...
# 1111                 False      0.828501
# 1112                 False      0.832124
# 1113                 False      0.831463
# 1114                 False      0.871904
# 1115                 False      0.965357
#
# [1116 rows x 12 columns], chip_tf=                                            name strand  Assay title  \
# 0                    CL:0000062 TF ChIP-seq CTCF      .  TF ChIP-seq
# 1                    CL:0000115 TF ChIP-seq CTCF      .  TF ChIP-seq
# 2                    CL:0000127 TF ChIP-seq CTCF      .  TF ChIP-seq
# 3                    CL:0000127 TF ChIP-seq EZH2      .  TF ChIP-seq
# 4                    CL:0000137 TF ChIP-seq CTCF      .  TF ChIP-seq
# ...                                          ...    ...          ...
# 1612             UBERON:0011907 TF ChIP-seq CTCF      .  TF ChIP-seq
# 1613           UBERON:0011907 TF ChIP-seq POLR2A      .  TF ChIP-seq
# 1614             UBERON:0036149 TF ChIP-seq CTCF      .  TF ChIP-seq
# 1615           UBERON:0036149 TF ChIP-seq POLR2A      .  TF ChIP-seq
# 1616  UBERON:0036149 TF ChIP-seq POLR2AphosphoS5      .  TF ChIP-seq
#
#       ontology_curie          biosample_name                 biosample_type  \
# 0         CL:0000062              osteoblast                   primary_cell
# 1         CL:0000115        endothelial cell  in_vitro_differentiated_cells
# 2         CL:0000127               astrocyte                   primary_cell
# 3         CL:0000127               astrocyte                   primary_cell
# 4         CL:0000137               osteocyte  in_vitro_differentiated_cells
# ...              ...                     ...                            ...
# 1612  UBERON:0011907  gastrocnemius medialis                         tissue
# 1613  UBERON:0011907  gastrocnemius medialis                         tissue
# 1614  UBERON:0036149         suprapubic skin                         tissue
# 1615  UBERON:0036149         suprapubic skin                         tissue
# 1616  UBERON:0036149         suprapubic skin                         tissue
#
#      biosample_life_stage transcription_factor data_source endedness  \
# 0                 unknown                 CTCF      encode    single
# 1                   adult                 CTCF      encode    single
# 2                 unknown                 CTCF      encode    single
# 3                 unknown                 EZH2      encode    single
# 4               embryonic                 CTCF      encode    single
# ...                   ...                  ...         ...       ...
# 1612                adult                 CTCF      encode    paired
# 1613                adult               POLR2A      encode    paired
# 1614                adult                 CTCF      encode    paired
# 1615                adult               POLR2A      encode    paired
# 1616                adult      POLR2AphosphoS5      encode    paired
#
#       genetically_modified  nonzero_mean
# 0                    False      1.464674
# 1                    False      0.841073
# 2                    False      1.393323
# 3                    False      0.959745
# 4                    False      0.839771
# ...                    ...           ...
# 1612                 False      0.741186
# 1613                 False      0.696144
# 1614                 False      0.793193
# 1615                 False      0.898075
# 1616                 False      0.830834
#
# [1617 rows x 12 columns], splice_sites=       name strand
# 0     donor      +
# 1  acceptor      +
# 2     donor      -
# 3  acceptor      -, splice_site_usage=                                                  name strand  \
# 0                  usage_CL:0000047 polyA plus RNA-seq      +
# 1                       usage_CL:0000062 total RNA-seq      +
# 2                  usage_CL:0000084 polyA plus RNA-seq      +
# 3                       usage_CL:0000084 total RNA-seq      +
# 4                       usage_CL:0000100 total RNA-seq      +
# ..                                                 ...    ...
# 729            usage_UBERON:0018116 polyA plus RNA-seq      -
# 730            usage_UBERON:0018117 polyA plus RNA-seq      -
# 731            usage_UBERON:0018118 polyA plus RNA-seq      -
# 732  usage_UBERON:0036149 gtex Skin_Not_Sun_Exposed...      -
# 733                 usage_UBERON:0036149 total RNA-seq      -
#
#             Assay title  ontology_curie                   biosample_name  \
# 0    polyA plus RNA-seq      CL:0000047               neuronal stem cell
# 1         total RNA-seq      CL:0000062                       osteoblast
# 2    polyA plus RNA-seq      CL:0000084                           T-cell
# 3         total RNA-seq      CL:0000084                           T-cell
# 4         total RNA-seq      CL:0000100                     motor neuron
# ..                  ...             ...                              ...
# 729  polyA plus RNA-seq  UBERON:0018116               right renal pelvis
# 730  polyA plus RNA-seq  UBERON:0018117   left renal cortex interstitium
# 731  polyA plus RNA-seq  UBERON:0018118  right renal cortex interstitium
# 732  polyA plus RNA-seq  UBERON:0036149                  suprapubic skin
# 733       total RNA-seq  UBERON:0036149                  suprapubic skin
#
#                     biosample_type biosample_life_stage  \
# 0    in_vitro_differentiated_cells            embryonic
# 1                     primary_cell                adult
# 2                     primary_cell                adult
# 3                     primary_cell                adult
# 4    in_vitro_differentiated_cells                adult
# ..                             ...                  ...
# 729                         tissue            embryonic
# 730                         tissue            embryonic
# 731                         tissue            embryonic
# 732                         tissue                adult
# 733                         tissue                adult
#
#                          gtex_tissue data_source
# 0                                         encode
# 1                                         encode
# 2                                         encode
# 3                                         encode
# 4                                         encode
# ..                               ...         ...
# 729                                       encode
# 730                                       encode
# 731                                       encode
# 732  Skin_Not_Sun_Exposed_Suprapubic        gtex
# 733                                       encode
#
# [734 rows x 9 columns], splice_junctions=                                                  name  ontology_curie  \
# 0               junction_CL:0000047 polyA plus RNA-seq      CL:0000047
# 1                    junction_CL:0000062 total RNA-seq      CL:0000062
# 2               junction_CL:0000084 polyA plus RNA-seq      CL:0000084
# 3                    junction_CL:0000084 total RNA-seq      CL:0000084
# 4                    junction_CL:0000100 total RNA-seq      CL:0000100
# ..                                                 ...             ...
# 362         junction_UBERON:0018116 polyA plus RNA-seq  UBERON:0018116
# 363         junction_UBERON:0018117 polyA plus RNA-seq  UBERON:0018117
# 364         junction_UBERON:0018118 polyA plus RNA-seq  UBERON:0018118
# 365  junction_UBERON:0036149 gtex Skin_Not_Sun_Expo...  UBERON:0036149
# 366              junction_UBERON:0036149 total RNA-seq  UBERON:0036149
#
#                       biosample_name                 biosample_type  \
# 0                 neuronal stem cell  in_vitro_differentiated_cells
# 1                         osteoblast                   primary_cell
# 2                             T-cell                   primary_cell
# 3                             T-cell                   primary_cell
# 4                       motor neuron  in_vitro_differentiated_cells
# ..                               ...                            ...
# 362               right renal pelvis                         tissue
# 363   left renal cortex interstitium                         tissue
# 364  right renal cortex interstitium                         tissue
# 365                  suprapubic skin                         tissue
# 366                  suprapubic skin                         tissue
#
#     biosample_life_stage                      gtex_tissue data_source  \
# 0              embryonic                                       encode
# 1                  adult                                       encode
# 2                  adult                                       encode
# 3                  adult                                       encode
# 4                  adult                                       encode
# ..                   ...                              ...         ...
# 362            embryonic                                       encode
# 363            embryonic                                       encode
# 364            embryonic                                       encode
# 365                adult  Skin_Not_Sun_Exposed_Suprapubic        gtex
# 366                adult                                       encode
#
#             Assay title
# 0    polyA plus RNA-seq
# 1         total RNA-seq
# 2    polyA plus RNA-seq
# 3         total RNA-seq
# 4         total RNA-seq
# ..                  ...
# 362  polyA plus RNA-seq
# 363  polyA plus RNA-seq
# 364  polyA plus RNA-seq
# 365  polyA plus RNA-seq
# 366       total RNA-seq
#
# [367 rows x 8 columns], contact_maps=                name strand    Assay title ontology_curie   biosample_name  \
# 0   4dn:4DNFI9GMP2J8      .        Micro-C    EFO:0003042          H1-hESC
# 1   4dn:4DNFI9FVHJZQ      .        Micro-C    EFO:0009318            HFFc6
# 2   4dn:4DNFIFLDVASC      .   in situ Hi-C    EFO:0002824           HCT116
# 3   4dn:4DNFIJTOIGOI      .   in situ Hi-C    EFO:0001196           IMR-90
# 4   4dn:4DNFIXP4QG5B      .   in situ Hi-C    EFO:0002784          GM12878
# 5   4dn:4DNFI2VYSX9M      .   in situ Hi-C    EFO:0007073            CyT49
# 6   4dn:4DNFI4DCV74I      .   in situ Hi-C    EFO:0003045               H9
# 7   4dn:4DNFI5IHU27G      .   in situ Hi-C    EFO:0005903            KBM-7
# 8   4dn:4DNFI6HDY7WZ      .   in situ Hi-C    EFO:0003042          H1-hESC
# 9   4dn:4DNFI82R42AD      .   in situ Hi-C    EFO:0003042          H1-hESC
# 10  4dn:4DNFI8RH55DO      .   in situ Hi-C    EFO:0003045               H9
# 11  4dn:4DNFIB59T7NN      .   in situ Hi-C    EFO:0009318            HFFc6
# 12  4dn:4DNFIBM9QCFG      .   in situ Hi-C    EFO:0002791          HeLa-S3
# 13  4dn:4DNFIIOUG5RF      .   in situ Hi-C    EFO:0003045               H9
# 14  4dn:4DNFIK3NF6R2      .   in situ Hi-C    EFO:0007073            CyT49
# 15  4dn:4DNFILP99QJS      .   in situ Hi-C    EFO:0002824           HCT116
# 16  4dn:4DNFIMDOXUT8      .  Dilution Hi-C     CL:0002620  skin fibroblast
# 17  4dn:4DNFINFQV712      .   in situ Hi-C    EFO:0003042          H1-hESC
# 18  4dn:4DNFINQYW56E      .        Micro-C    EFO:0003042          H1-hESC
# 19  4dn:4DNFINXSKZ4F      .   in situ Hi-C    EFO:0007073            CyT49
# 20  4dn:4DNFIPO1DGLH      .   in situ Hi-C    EFO:0003045               H9
# 21  4dn:4DNFIRO3DQCO      .   in situ Hi-C    EFO:0003045               H9
# 22  4dn:4DNFIS6HAUPP      .   in situ Hi-C    EFO:0001187            HepG2
# 23  4dn:4DNFIT5YVTLO      .   in situ Hi-C    EFO:0003045               H9
# 24  4dn:4DNFIVKQADWM      .   in situ Hi-C    EFO:0009747          GM25256
# 25  4dn:4DNFIW8IXCX1      .   in situ Hi-C    EFO:0003042          H1-hESC
# 26  4dn:4DNFIXOWKAM6      .   in situ Hi-C    EFO:0007073            CyT49
# 27  4dn:4DNFIYGPDLKF      .   in situ Hi-C    EFO:0009747          GM25256
#
#                    biosample_type data_source
# 0                       cell_line  4dnucleome
# 1                       cell_line  4dnucleome
# 2                       cell_line  4dnucleome
# 3                       cell_line  4dnucleome
# 4                       cell_line  4dnucleome
# 5                       cell_line  4dnucleome
# 6                       cell_line  4dnucleome
# 7                       cell_line  4dnucleome
# 8                       cell_line  4dnucleome
# 9                       cell_line  4dnucleome
# 10                      cell_line  4dnucleome
# 11                      cell_line  4dnucleome
# 12                      cell_line  4dnucleome
# 13                      cell_line  4dnucleome
# 14                      cell_line  4dnucleome
# 15                      cell_line  4dnucleome
# 16                      cell_line  4dnucleome
# 17                      cell_line  4dnucleome
# 18                      cell_line  4dnucleome
# 19                      cell_line  4dnucleome
# 20                      cell_line  4dnucleome
# 21                      cell_line  4dnucleome
# 22                      cell_line  4dnucleome
# 23                      cell_line  4dnucleome
# 24  in_vitro_differentiated_cells  4dnucleome
# 25                      cell_line  4dnucleome
# 26                      cell_line  4dnucleome
# 27  in_vitro_differentiated_cells  4dnucleome  , procap=           name strand Assay title ontology_curie  \
# 0   ENCSR072YCM      +     PRO-cap    EFO:0002106
# 1   ENCSR182QNJ      +     PRO-cap    EFO:0001099
# 2   ENCSR740IPL      +     PRO-cap    EFO:0002067
# 3   ENCSR797DEF      +     PRO-cap    EFO:0002819
# 4   ENCSR801ECP      +     PRO-cap     CL:0002618
# 5   ENCSR860TYZ      +     PRO-cap    EFO:0001200
# 6   ENCSR072YCM      -     PRO-cap    EFO:0002106
# 7   ENCSR182QNJ      -     PRO-cap    EFO:0001099
# 8   ENCSR740IPL      -     PRO-cap    EFO:0002067
# 9   ENCSR797DEF      -     PRO-cap    EFO:0002819
# 10  ENCSR801ECP      -     PRO-cap     CL:0002618
# 11  ENCSR860TYZ      -     PRO-cap    EFO:0001200
#
#                         biosample_name biosample_type data_source  \
# 0                                 A673      cell_line      encode
# 1                               Caco-2      cell_line      encode
# 2                                 K562      cell_line      encode
# 3                                Calu3      cell_line      encode
# 4   endothelial cell of umbilical vein   primary_cell      encode
# 5                              MCF 10A      cell_line      encode
# 6                                 A673      cell_line      encode
# 7                               Caco-2      cell_line      encode
# 8                                 K562      cell_line      encode
# 9                                Calu3      cell_line      encode
# 10  endothelial cell of umbilical vein   primary_cell      encode
# 11                             MCF 10A      cell_line      encode
#
#     genetically_modified  nonzero_mean
# 0                  False     13.308302
# 1                  False     14.002803
# 2                  False     15.765458
# 3                  False     12.281321
# 4                  False     13.973692
# 5                  False      8.229502
# 6                  False     13.308302
# 7                  False     14.002803
# 8                  False     15.765458
# 9                  False     12.281321
# 10                 False     13.973692
# 11                 False      8.229502  )

# %%
# Load gene annotations (from GENCODE).
gtf = pd.read_feather(
    'https://storage.googleapis.com/alphagenome/reference/gencode/'
    'hg38/gencode.v46.annotation.gtf.gz.feather'
)

# Filter to protein-coding genes and highly supported transcripts.
gtf_transcript = gene_annotation.filter_transcript_support_level(
    gene_annotation.filter_protein_coding(gtf), ['1']
)

# Extractor for identifying transcripts in a region.
transcript_extractor = transcript.TranscriptExtractor(gtf_transcript)

# Also define an extractor that fetches only the longest transcript per gene.
gtf_longest_transcript = gene_annotation.filter_to_longest_transcript(
    gtf_transcript
)
longest_transcript_extractor = transcript.TranscriptExtractor(
    gtf_longest_transcript
)

# %% [markdown]
# Visualise gene expression - RNA-seq and CAGE

# %%
# @title Visualise gene expression - RNA-seq and CAGE
# Define interval to make predictions.
# Note that the interval width must be one of the supported sequence lengths.
interval = genome.Interval('chr19', 50_150_000, 51_150_000).resize(
    dna_client.SEQUENCE_LENGTH_1MB
)

# Define the tissues/cell-types to predict expression for.
ontology_terms = [
        'UBERON:0002367',  # Prostate gland
    "EFO:0005726", # prostate cancer LNCaP
    "EFO:00002074" # prostate cancer PC3
]

# Make predictions.
output = dna_model.predict_interval(
    interval=interval,
    requested_outputs={
        dna_client.OutputType.RNA_SEQ,
        dna_client.OutputType.CAGE,
    },
    ontology_terms=ontology_terms,
)

# Extract the longest transcripts per gene for this interval.
longest_transcripts = longest_transcript_extractor.extract(interval)

# %%
#  @title Build plot.
plot = plot_components.plot(
    [
        plot_components.TranscriptAnnotation(longest_transcripts),
        plot_components.Tracks(
            tdata=output.rna_seq,
            ylabel_template='RNA_SEQ: {biosample_name} ({strand})\n{name}',
        ),
        plot_components.Tracks(
            tdata=output.cage,
            ylabel_template='CAGE: {biosample_name} ({strand})\n{name}',
        ),
    ],
    interval=interval,
    title='Predicted RNA Expression (RNA_SEQ, CAGE) for prostate tissue',
)

# %% [markdown]
# Visualize the effect of a variant in CTCF binding site

# %%
# Define the variant of interest.
variant_string = 'chr19:50845834:G>T'
variant = genome.Variant.from_str(variant_string)
variant
# Out:
# Variant(chromosome='chr19', position=50845834, reference_bases='G', alternate_bases='T', name='')

# %%
# Make predictions for sequences containing the REF and ALT alleles.
output = dna_model.predict_variant(
    interval=interval,
    variant=variant,
    requested_outputs={
        dna_client.OutputType.RNA_SEQ,
        dna_client.OutputType.CAGE,
    },
    ontology_terms=ontology_terms,
)

# %%
# Zoom in on the region around KLK4.
klk4_interval = gene_annotation.get_gene_interval(gtf, gene_symbol='KLK4')

# Add 1KB on either side of the gene body.
klk4_interval.resize_inplace(klk4_interval.width + 1000)

# %%
# Zoom in on the region around KLK3.
klk3_interval = gene_annotation.get_gene_interval(gtf, gene_symbol='KLK3')

# Add 1KB on either side of the gene body.
klk3_interval.resize_inplace(klk3_interval.width + 10000)

# %%
#@ Build plot
# Define the colors for REF and ALT predictions.
ref_alt_colors = {'REF': 'dimgrey', 'ALT': 'red'}

# Build plot.
plot = plot_components.plot(
    [
        plot_components.TranscriptAnnotation(longest_transcripts),
        # RNA-seq tracks.
        plot_components.OverlaidTracks(
            tdata={
                'REF': output.reference.rna_seq.filter_to_nonpositive_strand(),
                'ALT': output.alternate.rna_seq.filter_to_nonpositive_strand(),
            },
            colors=ref_alt_colors,
            ylabel_template='{biosample_name} ({strand})\n{name}',
        ),
        # CAGE track.
        plot_components.OverlaidTracks(
            tdata={
                'REF': output.reference.cage.filter_to_nonpositive_strand(),
                'ALT': output.alternate.cage.filter_to_nonpositive_strand(),
            },
            colors=ref_alt_colors,
            ylabel_template='{biosample_name} ({strand})\n{name}',
        ),
    ],
    annotations=[plot_components.VariantAnnotation([variant])],
    interval=klk3_interval,
    title='Effect of variant on predicted RNA Expression in prostate tissue',
)

# %%
#@ Build plot
# Define the colors for REF and ALT predictions.
ref_alt_colors = {'REF': 'dimgrey', 'ALT': 'red'}

# Build plot.
plot = plot_components.plot(
    [
        plot_components.TranscriptAnnotation(longest_transcripts),
        # RNA-seq tracks.
        plot_components.OverlaidTracks(
            tdata={
                'REF': output.reference.rna_seq.filter_to_nonpositive_strand(),
                'ALT': output.alternate.rna_seq.filter_to_nonpositive_strand(),
            },
            colors=ref_alt_colors,
            ylabel_template='{biosample_name} ({strand})\n{name}',
        ),
        # CAGE track.
        plot_components.OverlaidTracks(
            tdata={
                'REF': output.reference.cage.filter_to_nonpositive_strand(),
                'ALT': output.alternate.cage.filter_to_nonpositive_strand(),
            },
            colors=ref_alt_colors,
            ylabel_template='{biosample_name} ({strand})\n{name}',
        ),
    ],
    annotations=[plot_components.VariantAnnotation([variant])],
    interval=klk4_interval,
    title='Effect of variant on predicted RNA Expression in prostate tissue',
)

# %% [markdown]
# Chromatin accessibility from DNAseq-seq and ATAC-seq

# %%
#  @title Chromatin Accessibility - DNAseq-seq and ATAC-seq
#Make predictions.
output = dna_model.predict_interval(
    interval,
    requested_outputs={
        dna_client.OutputType.DNASE,
        dna_client.OutputType.ATAC,
    },
    ontology_terms=ontology_terms,
)

# %%
#  @title Build plot.
plot = plot_components.plot(
    [
        plot_components.TranscriptAnnotation(longest_transcripts),
        plot_components.Tracks(
            tdata=output.dnase,
            ylabel_template='DNASE: {biosample_name} ({strand})\n{name}',
        ),
        plot_components.Tracks(
            tdata=output.atac,
            ylabel_template='ATAC: {biosample_name} ({strand})\n{name}',
        ),
    ],
    interval=interval,
    title='Predicted chromatin accessibility (DNASE, ATAC) for prostate tissue',
)

# %% [markdown]
# ChIP - Transcription factor binding:

# %%
# @title ChIP-seq transcriptin factor (TF) binding
ontology_terms = [
    'UBERON:0002367',  # Prostate gland
    "EFO:0005726", # prostate cancer LNCaP
    "EFO:00002074" # prostate cancer PC3
]

output = dna_model.predict_interval(
    interval=interval,
    requested_outputs={dna_client.OutputType.CHIP_TF},
    ontology_terms=ontology_terms,
)

# %%
output_chip_tf = output.chip_tf.filter_tracks(
    (output.chip_tf.metadata['ontology_curie'].isin(ontology_terms)).values
)
len(output_chip_tf.metadata)

# %%
#  @title Build plot.
plot_components.plot(
    [
        plot_components.TranscriptAnnotation(longest_transcripts),
        plot_components.Tracks(
            tdata=output_chip_tf,
            ylabel_template=
                'CHIP TF: {biosample_name} ({strand})\n{transcription_factor}'
            ),
    ],
    interval=interval,
    title='Predicted TF-binding in Prostate gland.'
)
plt.show()

# %% [markdown]
# 3D contact maps

# %%
# @title 3D Chromatin contacts from Hi-C data
ontology_terms = [
    "EFO:0005726",  # LNCaP prostate cancer cell line.
]

output = dna_model.predict_interval(
    interval=interval,
    requested_outputs={dna_client.OutputType.CONTACT_MAPS},
    ontology_terms=ontology_terms,
)

# %%
# @title Build plot
plot = plot_components.plot(
    [
        plot_components.TranscriptAnnotation(longest_transcripts),
        plot_components.ContactMaps(
            tdata=output.contact_maps,
            ylabel_template='{biosample_name}\n{name}',
            cmap='autumn_r',
            vmax=1.0,
        ),
    ],
    interval=interval,
    title='Predicted contact maps',
)
plt.show()

# %%
#  @title Plot 3D chromatin contacts based on a different dataset
ontology_terms = [
    'EFO:0002824',  # HCT116 colon carcinoma cell line.
]

output = dna_model.predict_interval(
    interval=interval,
    requested_outputs={dna_client.OutputType.CONTACT_MAPS},
    ontology_terms=ontology_terms,
)

# %%
# @title Build plot
plot = plot_components.plot(
    [
        plot_components.TranscriptAnnotation(longest_transcripts),
        plot_components.ContactMaps(
            tdata=output.contact_maps,
            ylabel_template='{biosample_name}\n{name}',
            cmap='autumn_r',
            vmax=1.0,
        ),
    ],
    interval=interval,
    title='Predicted contact maps',
)
plt.show()
